# %%
import pandas as pd

# Load the Excel file
df = pd.read_excel('constant_dollar_expenditures.xlsx')
df.head()
# Out:
#   Constant dollar food and alcohol expenditures, with taxes and tips, for all purchasers  \
# 0              (Millions of U.S. dollars (1988=100))
# 1                                                NaN
# 2                                                NaN
# 3                                               Year
# 4                                               1997
#
#            Unnamed: 1          Unnamed: 2         Unnamed: 3  \
# 0                 NaN                 NaN                NaN
# 1  Food at home (FAH)                 NaN                NaN
# 2               Sales                 NaN                NaN
# 3      Grocery stores  Convenience stores  Other food stores
# 4       199832.859375         7201.876953        7899.325195
#
#                          Unnamed: 4                    Unnamed: 5  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# ...

# %%
#Clean the data
#Missing Values
df.dropna(inplace=True)
#Removing duplicates
df.drop_duplicates(inplace=True)
# Renaming columns
df.rename(columns={'Unamed:1': 'Grocery Stores'}, inplace=True)
df
# Out:
#    Constant dollar food and alcohol expenditures, with taxes and tips, for all purchasers  \
# 3                                                Year
# 4                                                1997
# 5                                                1998
# 6                                                1999
# 7                                                2000
# 8                                                2001
# 9                                                2002
# 10                                               2003
# 11                                               2004
# 12                                               2005
# 13                                               2006
# 14                                               2007
# 15                                               2008
# 16                                               2009
# 17                                               2010
# 18                                               2011
# ...
