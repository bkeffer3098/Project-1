# %%
#Import Dependencies
import pandas as pd
#!pip install seaborn
import seaborn as sns

# %%
df=pd.read_excel("../Resources/constant_dollar_expenditures.xlsx")
df.isnull().sum()
# Out:
# Year                                                          0
# Grocery stores                                                0
# Convenience stores                                            0
# Other food stores                                             0
# Warehouse clubs and supercenters                              0
# Other stores and foodservice                                  0
# Mail order and home delivery                                  0
# Direct selling by farmers, manufacturers, and wholesalers     0
# Home production and donations                                 0
# Total FAH                                                     0
# Unnamed: 10                                                  26
# Full-service restaurants                                      0
# Limited-service restaurants                                   0
# Drinking places                                               0
# Hotels and motels                                             0
# Retail stores and vending                                     0
# Recreational places                                           0
# Schools and colleges                                          0
# Other FAFH sales, NEC                                         0
# Food furnished and donated                                    0
# Total FAFH                                                    0
# Unnamed: 21                                                  26
# Liquor stores                                                 0
# Food stores                                                   0
# Other AAH sales, NEC                                          0
# Total AAH                                                     0
# Unnamed: 26                                                  26
# Eating and drinking places                                    0
# Hotels and motels.1                                           0
# Other AAFH, NEC                                               0
# Total AAFH                                                    0
# dtype: int64

# %%
df
df=df.drop(columns=['Unnamed: 10','Unnamed: 21','Unnamed: 26','Eating and drinking places','Hotels and motels.1','Other AAFH, NEC','Total AAFH','Full-service restaurants',
 'Limited-service restaurants',
 'Drinking places',
 'Hotels and motels',
 'Retail stores and vending',
 'Recreational places',
 'Schools and colleges',
 'Other FAFH sales, NEC',
 'Food furnished and donated',
 'Total FAFH',
 'Liquor stores',
 'Food stores',
 'Other AAH sales, NEC',
 'Total AAH'])
column_list=df.columns.tolist()
pd.set_option('display.max_columns', None)
column_list
# Out:
# ['Year',
#  'Grocery stores',
#  'Convenience stores',
#  'Other food stores',
#  'Warehouse clubs and supercenters',
#  'Other stores and foodservice',
#  'Mail order and home delivery',
#  'Direct selling by farmers, manufacturers, and wholesalers',
#  'Home production and donations',
#  'Total FAH']

# %%
df[df.Year > 2009]
df=df[df.Year > 2009]
df[df.Year < 2021]
df=df[df.Year < 2021]
df
# Out:
#     Year  Grocery stores  Convenience stores  Other food stores  \
# 13  2010   195126.812500         5588.208496        8016.354492
# 14  2011   194311.921875         5959.961914        8071.914551
# 15  2012   193891.093750         6205.290039        8305.420898
# 16  2013   194480.156250         6177.100098        8191.985352
# 17  2014   197283.078125         5885.266113        8342.761719
# 18  2015   198563.218750         5495.631836        8331.321289
# 19  2016   203168.656250         5675.934570        8596.593750
# 20  2017   210027.187500         5712.197266        8526.469727
# 21  2018   214318.921875         6263.274902        8651.769531
# 22  2019   219674.953125         6421.435059        8629.272461
# 23  2020   233877.687500         5886.300781        8545.722656
#
#     Warehouse clubs and supercenters  Other stores and foodservice  \
# 13                      74881.320312                  33873.296875
# 14                      74420.742188                  36257.882812
# 15                      87753.421875                  35959.937500
# 16                      88258.781250                  36335.683594
# 17                      87924.226562                  36219.988281
# 18                      87595.296875                  33417.117188
# 19                      88729.265625                  33713.507812
# 20                      89588.015625                  35962.023438
# 21                      91724.890625                  38153.433594
# 22                      92888.640625                  37792.246094
# 23                      93198.375000                  34400.832031
#
#     Mail order and home delivery  \
# 13                   9355.090820
# 14                   9333.718750
# 15                   9376.705078
# 16                  11115.856445
# 17                  13074.513672
# 18                  15253.492188
# 19                  18719.259766
# 20                  22945.041016
# 21                  25286.880859
# 22                  27705.365234
# 23                  33042.703125
#
#     Direct selling by farmers, manufacturers, and wholesalers  \
# 13                                        1904.630127
# 14                                        1913.728638
# 15                                        1931.728149
# 16                                        2402.576904
# 17                                        2836.614990
# 18                                        3228.386719
# 19                                        3410.132812
# 20                                        3463.389404
# 21                                        3489.534180
# 22                                        3509.914307
# 23                                        3430.923096
#
#     Home production and donations     Total FAH
# 13                    1018.687378  329764.40625
# 14                     788.896118  331058.78125
# 15                     745.240479  344168.84375
# 16                     903.966431  347866.12500
# 17                     908.755432  352475.21875
# 18                    1042.415894  352926.87500
# 19                    1056.962646  363070.28125
# 20                     920.527405  377144.84375
# 21                     957.538208  388846.25000
# 22                    1028.907593  397650.75000
# 23                    1031.436890  413414.00000

# %%
sns.barplot(x="Year",data=df, y="Total FAH")
# Out:
# C:\Users\janka\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\janka\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\janka\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Year', ylabel='Total FAH'>

# %%
df.pivot(index="Year", columns="Total FAH", values="Total FAH")
# Out:
# Total FAH  329764.40625  331058.78125  344168.84375  347866.12500  \
# Year
# 2010       329764.40625           NaN           NaN           NaN
# 2011                NaN  331058.78125           NaN           NaN
# 2012                NaN           NaN  344168.84375           NaN
# 2013                NaN           NaN           NaN    347866.125
# 2014                NaN           NaN           NaN           NaN
# 2015                NaN           NaN           NaN           NaN
# 2016                NaN           NaN           NaN           NaN
# 2017                NaN           NaN           NaN           NaN
# 2018                NaN           NaN           NaN           NaN
# 2019                NaN           NaN           NaN           NaN
# 2020                NaN           NaN           NaN           NaN
#
# Total FAH  352475.21875  352926.87500  363070.28125  377144.84375  \
# Year
# 2010                NaN           NaN           NaN           NaN
# 2011                NaN           NaN           NaN           NaN
# 2012                NaN           NaN           NaN           NaN
# 2013                NaN           NaN           NaN           NaN
# 2014       352475.21875           NaN           NaN           NaN
# 2015                NaN    352926.875           NaN           NaN
# 2016                NaN           NaN  363070.28125           NaN
# 2017                NaN           NaN           NaN  377144.84375
# 2018                NaN           NaN           NaN           NaN
# 2019                NaN           NaN           NaN           NaN
# 2020                NaN           NaN           NaN           NaN
#
# Total FAH  388846.25000  397650.75000  413414.00000
# Year
# 2010                NaN           NaN           NaN
# 2011                NaN           NaN           NaN
# 2012                NaN           NaN           NaN
# 2013                NaN           NaN           NaN
# 2014                NaN           NaN           NaN
# 2015                NaN           NaN           NaN
# 2016                NaN           NaN           NaN
# 2017                NaN           NaN           NaN
# 2018          388846.25           NaN           NaN
# 2019                NaN     397650.75           NaN
# 2020                NaN           NaN      413414.0
