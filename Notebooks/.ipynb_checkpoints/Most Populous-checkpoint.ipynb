# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import data
state_data = Path("../Resources/state_sales.xlsx")

#Read the data
read_state = pd.read_excel(state_data)
read_state
# Out:
#       Year    State          FAH         FAFH  \
# 0     1997  Alabama  4469.228516  2784.981934
# 1     1998  Alabama  4524.197266  2901.213623
# 2     1999  Alabama  4733.012207  3036.594238
# 3     2000  Alabama  4804.239746  3262.472656
# 4     2001  Alabama  4822.866699  3038.350830
# ...    ...      ...          ...          ...
# 1219  2016  Wyoming   641.394897   645.485962
# 1220  2017  Wyoming   615.267395   663.478088
# 1221  2018  Wyoming   649.797852   691.046997
# 1222  2019  Wyoming   664.854492   705.335571
# 1223  2020  Wyoming   725.427185   562.053772
#
#       Total constant dollar food sales
# 0                          7254.210449
# 1                          7425.411133
# 2                          7769.606445
# 3                          8066.712402
# 4                          7861.217773
# ...                                ...
# 1219                       1286.880859
# 1220                       1278.745483
# 1221                       1340.844849
# 1222                       1370.190063
# 1223                       1287.480957
#
# [1224 rows x 5 columns]

# %%
#Slim down the data to the states I need
populous_states = read_state.loc[(read_state['State'] == "California") | (read_state['State'] == "New York") |
                            (read_state['State'] == "Florida") | (read_state['State'] == "Ohio") |
                            (read_state['State'] == "Texas"),:]
populous_states
# Out:
#       Year       State           FAH          FAFH  \
# 96    1997  California  31514.435547  26467.984375
# 97    1998  California  31649.806641  27334.140625
# 98    1999  California  32559.091797  28035.632812
# 99    2000  California  32984.589844  29664.906250
# 100   2001  California  33758.070312  30200.503906
# ...    ...         ...           ...           ...
# 1051  2016       Texas  30882.050781  30484.568359
# 1052  2017       Texas  32037.693359  31792.515625
# 1053  2018       Texas  33249.726562  33400.488281
# 1054  2019       Texas  33918.125000  34657.222656
# 1055  2020       Texas  35040.027344  28784.640625
#
#       Total constant dollar food sales
# 96                        57982.421875
# 97                        58983.945312
# 98                        60594.726562
# 99                        62649.496094
# 100                       63958.574219
# ...                                ...
# 1051                      61366.617188
# 1052                      63830.210938
# 1053                      66650.218750
# 1054                      68575.343750
# 1055                      63824.667969
#
# [120 rows x 5 columns]

# %%
#Slim down to the last 10 years. 
populous_states = populous_states.loc[(populous_states['Year'] >= 2010) ,:]

populous_states.head()
# Out:
#      Year       State           FAH          FAFH  \
# 109  2010  California  36127.195312  35316.398438
# 110  2011  California  37312.789062  36889.839844
# 111  2012  California  37227.148438  37511.402344
# 112  2013  California  39007.109375  39465.593750
# 113  2014  California  40992.820312  41607.484375
#
#      Total constant dollar food sales
# 109                      71443.593750
# 110                      74202.625000
# 111                      74738.546875
# 112                      78472.703125
# 113                      82600.304688

# %%
california_df = populous_states.loc[(populous_states['State'] == "California") ,:]
newyork_df = populous_states.loc[(populous_states['State'] == "New York") ,:]
texas_df = populous_states.loc[(populous_states['State'] == "Texas") ,:]
florida_df = populous_states.loc[(populous_states['State'] == "Florida") ,:]
ohio_df = populous_states.loc[(populous_states['State'] == "Ohio") ,:]

# %%
#line plot that shows the FAH spending per state
#each state has a different x and y 

x_cal = california_df["Year"]
y_cal = california_df["FAFH"]

x_ny = newyork_df["Year"]
y_ny = newyork_df["FAFH"]

x_tex = texas_df["Year"]
y_tex = texas_df["FAFH"]

x_flo = florida_df["Year"]
y_flo = florida_df["FAFH"]

x_ohio = ohio_df["Year"]
y_ohio = ohio_df["FAFH"]

# %%
#plotting

plt.plot(x_cal, y_cal,marker="+",color="red", linewidth=1, label="California")
plt.plot(x_ny, y_ny,marker="+",color="blue", linewidth=1, label="New York")
plt.plot(x_tex, y_tex,marker="+",color="green", linewidth=1, label="Texas")
plt.plot(x_flo, y_flo,marker="+",color="black", linewidth=1, label="Florida")
plt.plot(x_ohio, y_ohio,marker="+",color="pink", linewidth=1, label="Ohio")


plt.xlabel("Years")
plt.ylabel("Sales (in Millions of Dollars)")
plt.title("Food Away From Home in Most Populous States")
plt.legend(loc="best", fontsize="8")

plt.savefig("../output_data/MostPopulousStatesFAFH.png")
plt.show()

# %%
#Creating a Bar Chart to show the most populous state's spending from 2010 to 2020
y_cal_fah = california_df["FAH"]

california_df = pd.DataFrame({
    "Years" : x_cal,
    "FAFH" : y_cal,
    "FAH": y_cal_fah})

california_df.plot(x="Years", y=["FAFH", "FAH"], kind="bar")

plt.title("California FAFH Vs. FAH")
plt.ylabel("Sales (in Millions of Dollars)")

plt.savefig("../output_data/CA_FAFH_VS_FAH.png")
plt.show()
